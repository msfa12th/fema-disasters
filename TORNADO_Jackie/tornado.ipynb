# %%
import pandas as pd
from sqlalchemy import create_engine
import os

# %%
csv_file = os.path.join("tornadorawdata.csv")
tornadoraw_data_df = pd.read_csv(csv_file)
tornadoraw_data_df
# Out:
#            om    yr  mo  dy        date      time  tz  st  stf  stn  ...  \
# 0           1  1950   1   3    1/3/1950  11:00:00   3  MO   29    1  ...
# 1           2  1950   1   3    1/3/1950  11:55:00   3  IL   17    2  ...
# 2           3  1950   1   3    1/3/1950  16:00:00   3  OH   39    1  ...
# 3           4  1950   1  13   1/13/1950   5:25:00   3  AR    5    1  ...
# 4           5  1950   1  25   1/25/1950  19:30:00   3  MO   29    2  ...
# 5           6  1950   1  25   1/25/1950  21:00:00   3  IL   17    3  ...
# 6           7  1950   1  26   1/26/1950  18:00:00   3  TX   48    1  ...
# 7           8  1950   2  11   2/11/1950  13:10:00   3  TX   48    2  ...
# 8           9  1950   2  11   2/11/1950  13:50:00   3  TX   48    3  ...
# 9          10  1950   2  11   2/11/1950  21:00:00   3  TX   48    4  ...
# 10         11  1950   2  11   2/11/1950  23:55:00   3  TX   48    5  ...
# 11         12  1950   2  12   2/12/1950   0:30:00   3  TX   48    6  ...
# ...

# %%
new_tornadoraw_data_df = tornadoraw_data_df[['om', 'date', 'st']].copy()
new_tornadoraw_data_df
# Out:
#            om        date  st
# 0           1    1/3/1950  MO
# 1           2    1/3/1950  IL
# 2           3    1/3/1950  OH
# 3           4   1/13/1950  AR
# 4           5   1/25/1950  MO
# 5           6   1/25/1950  IL
# 6           7   1/26/1950  TX
# 7           8   2/11/1950  TX
# 8           9   2/11/1950  TX
# 9          10   2/11/1950  TX
# 10         11   2/11/1950  TX
# 11         12   2/12/1950  TX
# 12         13   2/12/1950  TX
# 13         14   2/12/1950  TX
# 14         15   2/12/1950  TX
# 15         16   2/12/1950  MS
# 16         17   2/12/1950  MS
# 17         18   2/12/1950  TX
# 18         19   2/12/1950  AR
# 19         20   2/12/1950  LA
# 20         21   2/12/1950  LA
# 21         22   2/12/1950  LA
# 22         23   2/12/1950  AR
# 23         24   2/12/1950  LA
# 24         25   2/13/1950  TN
# 25         26   2/13/1950  TN
# 26         27   2/27/1950  OK
# 27         28    3/1/1950  MS
# 28         29   3/16/1950  FL
# 29         30   3/19/1950  LA
# ...

# %%
rds_connection_string = "postgres:Dbadmin@localhost:5432/NaturalDisaster_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['location',
#  'data_source',
#  'natural_disaster',
#  'fema',
#  'wild_fire',
#  'earthquake',
#  'tornado']

# %%
new_tornadoraw_data_df[['date']].head
# Out:
# <bound method NDFrame.head of              date
# 0        1/3/1950
# 1        1/3/1950
# 2        1/3/1950
# 3       1/13/1950
# 4       1/25/1950
# ...           ...
# 63640  12/27/2018
# 63641  12/27/2018
# 63642  12/31/2018
# 63643  12/31/2018
# 63644  12/31/2018
#
# [63645 rows x 1 columns]>

# %%
date_df=new_tornadoraw_data_df[['date']]

# %%
om_df=new_tornadoraw_data_df[['om']]

# %%
date_df
# Out:
# <bound method NDFrame.head of              date
# 0        1/3/1950
# 1        1/3/1950
# 2        1/3/1950
# 3       1/13/1950
# 4       1/25/1950
# ...           ...
# 63640  12/27/2018
# 63641  12/27/2018
# 63642  12/31/2018
# 63643  12/31/2018
# 63644  12/31/2018
#
# [63645 rows x 1 columns]>

# %%
nd_data = {
          'event_id': om_df
          'event_date': date_df
          }

nd_data_df=pd.DataFrame(data=nd_data, index=[0])

nd_data_df.head()
# Out:
#   File "<ipython-input-33-f67203291b2e>", line 3
#     'event_date': date_df
#                ^
# SyntaxError: invalid syntax

# %%
nd_data = {'data_source': "TORNADO",
          'event_id': new_tornadoraw_data_df[['om']],
          'event_date': new_tornadoraw_data_df[['date']],
          'event_type': "TORNADO",
          'state': new_tornadoraw_data_df[['state']]
          }

nd_data_df=pd.DataFrame(data=nd_data, index=[0])

nd_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-5146f2818ab4> in <module>
#       3           'event_date': new_tornadoraw_data_df[['date']],
#       4           'event_type': "TORNADO",
# ----> 5           'state': new_tornadoraw_data_df[['state']]
#       6           }
#       7
#
# ~\.conda\envs\pythondata\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# ~\.conda\envs\pythondata\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
# ...
