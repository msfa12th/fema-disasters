# %%
import pandas as pd
from sqlalchemy import create_engine
import os

# %%
csv_file = os.path.join("tornadorawdata.csv")
tornadoraw_data_df = pd.read_csv(csv_file)
tornadoraw_data_df
# Out:
#           id      om  data_source    yr  mo  dy        date      time  tz  st  \
# 0          1       1            5  1950   1   3    1/3/1950  11:00:00   3  MO
# 1          2       2            5  1950   1   3    1/3/1950  11:55:00   3  IL
# 2          3       3            5  1950   1   3    1/3/1950  16:00:00   3  OH
# 3          4       4            5  1950   1  13   1/13/1950   5:25:00   3  AR
# 4          5       5            5  1950   1  25   1/25/1950  19:30:00   3  MO
# ...      ...     ...          ...   ...  ..  ..         ...       ...  ..  ..
# 63640  63641  617020            5  2018  12  27  12/27/2018  10:15:00   3  LA
# 63641  63642  617021            5  2018  12  27  12/27/2018  10:29:00   3  MS
# 63642  63643  617022            5  2018  12  31  12/31/2018  12:35:00   3  KY
# 63643  63644  617023            5  2018  12  31  12/31/2018  13:43:00   3  IN
# 63644  63645  617024            5  2018  12  31  12/31/2018  14:38:00   3  IN
#
#        ...   len  wid  ns  sn  sg   f1  f2  f3  f4  fc
# 0      ...  9.50  150   2   0   1    0   0   0   0   0
# 1      ...  3.60  130   1   1   1  135   0   0   0   0
# 2      ...  0.10   10   1   1   1  161   0   0   0   0
# 3      ...  0.60   17   1   1   1  113   0   0   0   0
# 4      ...  2.30  300   1   1   1   93   0   0   0   0
# ...    ...   ...  ...  ..  ..  ..  ...  ..  ..  ..  ..
# 63640  ...  0.60   25   1   1   1    1   0   0   0   0
# 63641  ...  1.29  100   1   1   1  163   0   0   0   0
# 63642  ...  0.76  125   1   1   1  221   0   0   0   0
# 63643  ...  2.01   50   1   1   1  147   0   0   0   0
# 63644  ...  2.20  140   1   1   1   61   0   0   0   0
#
# [63645 rows x 31 columns]

# %%
new_tornadoraw_data_df = tornadoraw_data_df[["id", "om", "data_source","yr", "mo", "dy", "date", "tz", "st", "stf", "stn",
         "mag", "inj", "fat", "loss","closs", "slat", "slon", "elat", "elon", "len", "wid","ns", "sn", "sg", "f1", "f2",
        "f3", "f4", "fc"]].copy()


new_tornadoraw_data_df
# Out:
#           id      om  data_source    yr  mo  dy        date  tz  st  stf  ...  \
# 0          1       1            5  1950   1   3    1/3/1950   3  MO   29  ...
# 1          2       2            5  1950   1   3    1/3/1950   3  IL   17  ...
# 2          3       3            5  1950   1   3    1/3/1950   3  OH   39  ...
# 3          4       4            5  1950   1  13   1/13/1950   3  AR    5  ...
# 4          5       5            5  1950   1  25   1/25/1950   3  MO   29  ...
# ...      ...     ...          ...   ...  ..  ..         ...  ..  ..  ...  ...
# 63640  63641  617020            5  2018  12  27  12/27/2018   3  LA   22  ...
# 63641  63642  617021            5  2018  12  27  12/27/2018   3  MS   28  ...
# 63642  63643  617022            5  2018  12  31  12/31/2018   3  KY   21  ...
# 63643  63644  617023            5  2018  12  31  12/31/2018   3  IN   18  ...
# 63644  63645  617024            5  2018  12  31  12/31/2018   3  IN   18  ...
#
#         len  wid  ns  sn  sg   f1  f2  f3  f4  fc
# 0      9.50  150   2   0   1    0   0   0   0   0
# 1      3.60  130   1   1   1  135   0   0   0   0
# 2      0.10   10   1   1   1  161   0   0   0   0
# 3      0.60   17   1   1   1  113   0   0   0   0
# 4      2.30  300   1   1   1   93   0   0   0   0
# ...     ...  ...  ..  ..  ..  ...  ..  ..  ..  ..
# 63640  0.60   25   1   1   1    1   0   0   0   0
# 63641  1.29  100   1   1   1  163   0   0   0   0
# 63642  0.76  125   1   1   1  221   0   0   0   0
# 63643  2.01   50   1   1   1  147   0   0   0   0
# 63644  2.20  140   1   1   1   61   0   0   0   0
#
# [63645 rows x 30 columns]

# %%
rds_connection_string = "postgres:postgres@localhost:5432/disasters_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['wild_fire', 'fema_disaster', 'tornado', 'data_source']

# %%
new_tornadoraw_data_df = new_tornadoraw_data_df.rename(columns = {"id": "id","om":  "om", "data_source": "data_source",
            "yr": "yr","mo": "mo", "dy": "dy",  "date": "date", "time":"time", "tz": "tz", "st": "states",
             "stf":"stf", "stn":"stn", "mag":"magnitude", "inj":"inj", "fat":"fat", "loss": "loss", "closs":"closs",
             "slat": "start_lat", "slon": "start_lon", "elat": "end_lat", "elon": "end_lon", "len":"len",
            "wid":"wid", "ns":"ns", "sn":"sn", "sg":"sg", "f1":"f1", "f2":"f2", "f3":"f3",  "f4":"f4", "fc":"fc"  })
                                      

new_tornadoraw_data_df.head()
# Out:
#    id  om  data_source    yr  mo  dy       date  tz states  stf  ...  len  \
# 0   1   1            5  1950   1   3   1/3/1950   3     MO   29  ...  9.5
# 1   2   2            5  1950   1   3   1/3/1950   3     IL   17  ...  3.6
# 2   3   3            5  1950   1   3   1/3/1950   3     OH   39  ...  0.1
# 3   4   4            5  1950   1  13  1/13/1950   3     AR    5  ...  0.6
# 4   5   5            5  1950   1  25  1/25/1950   3     MO   29  ...  2.3
#
#    wid  ns  sn  sg   f1  f2  f3  f4  fc
# 0  150   2   0   1    0   0   0   0   0
# 1  130   1   1   1  135   0   0   0   0
# 2   10   1   1   1  161   0   0   0   0
# 3   17   1   1   1  113   0   0   0   0
# 4  300   1   1   1   93   0   0   0   0
#
# [5 rows x 30 columns]

# %%
new_tornadoraw_data_df.to_sql(name='tornado', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\.conda\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#
# ~\.conda\envs\pythondata\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# UniqueViolation: duplicate key value violates unique constraint "pk_tornado"
# DETAIL:  Key (id)=(1) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-7-c06c6cf43978> in <module>
# ----> 1 new_tornadoraw_data_df.to_sql(name='tornado', con=engine, if_exists='append', index=False)
#
# ~\.conda\envs\pythondata\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# ~\.conda\envs\pythondata\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# ~\.conda\envs\pythondata\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1318         )
#    1319         table.create()
# -> 1320         table.insert(chunksize, method=method)
#    1321         if not name.isdigit() and not name.islower():
#    1322             # check for potentially case sensitivity issues (GH7815)
#
# ~\.conda\envs\pythondata\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     754
#     755                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 756                 exec_insert(conn, keys, chunk_iter)
#     757
#     758     def _query_iterator(
#
# ~\.conda\envs\pythondata\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     668         """
#     669         data = [dict(zip(keys, row)) for row in data_iter]
# --> 670         conn.execute(self.table.insert(), data)
#     671
#     672     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\.conda\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\.conda\envs\pythondata\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\.conda\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\.conda\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# ~\.conda\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# ~\.conda\envs\pythondata\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\.conda\envs\pythondata\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\.conda\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1227                 if not evt_handled:
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#    1231             elif not parameters and context.no_parameters:
#
# ~\.conda\envs\pythondata\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "pk_tornado"
# DETAIL:  Key (id)=(1) already exists.
#
# [SQL: INSERT INTO tornado (id, om, data_source, yr, mo, dy, date, tz, states, stf, stn, magnitude, inj, fat, loss, closs, start_lat, start_lon, end_lat, end_lon, len, wid, ns, sn, sg, f1, f2, f3, f4, fc) VALUES (%(id)s, %(om)s, %(data_source)s, %(yr)s, %(mo)s, %(dy)s, %(date)s, %(tz)s, %(states)s, %(stf)s, %(stn)s, %(magnitude)s, %(inj)s, %(fat)s, %(loss)s, %(closs)s, %(start_lat)s, %(start_lon)s, %(end_lat)s, %(end_lon)s, %(len)s, %(wid)s, %(ns)s, %(sn)s, %(sg)s, %(f1)s, %(f2)s, %(f3)s, %(f4)s, %(fc)s)]
# [parameters: ({'id': 1, 'om': 1, 'data_source': 5, 'yr': 1950, 'mo': 1, 'dy': 3, 'date': '1/3/1950', 'tz': 3, 'states': 'MO', 'stf': 29, 'stn': 1, 'magnitude': 3, 'inj': 3, 'fat': 0, 'loss': 6.0, 'closs': 0.0, 'start_lat': 38.77, 'start_lon': -90.22, 'end_lat': 38.83, 'end_lon': -90.03, 'len': 9.5, 'wid': 150, 'ns': 2, 'sn': 0, 'sg': 1, 'f1': 0, 'f2': 0, 'f3': 0, 'f4': 0, 'fc': 0}, {'id': 2, 'om': 2, 'data_source': 5, 'yr': 1950, 'mo': 1, 'dy': 3, 'date': '1/3/1950', 'tz': 3, 'states': 'IL', 'stf': 17, 'stn': 2, 'magnitude': 3, 'inj': 3, 'fat': 0, 'loss': 5.0, 'closs': 0.0, 'start_lat': 39.1, 'start_lon': -89.3, 'end_lat': 39.12, 'end_lon': -89.23, 'len': 3.6, 'wid': 130, 'ns': 1, 'sn': 1, 'sg': 1, 'f1': 135, 'f2': 0, 'f3': 0, 'f4': 0, 'fc': 0}, {'id': 3, 'om': 3, 'data_source': 5, 'yr': 1950, 'mo': 1, 'dy': 3, 'date': '1/3/1950', 'tz': 3, 'states': 'OH', 'stf': 39, 'stn': 1, 'magnitude': 1, 'inj': 1, 'fat': 0, 'loss': 4.0, 'closs': 0.0, 'start_lat': 40.88, 'start_lon': -84.58, 'end_lat': 0.0, 'end_lon': 0.0, 'len': 0.1, 'wid': 10, 'ns': 1, 'sn': 1, 'sg': 1, 'f1': 161, 'f2': 0, 'f3': 0, 'f4': 0, 'fc': 0}, {'id': 4, 'om': 4, 'data_source': 5, 'yr': 1950, 'mo': 1, 'dy': 13, 'date': '1/13/1950', 'tz': 3, 'states': 'AR', 'stf': 5, 'stn': 1, 'magnitude': 3, 'inj': 1, 'fat': 1, 'loss': 3.0, 'closs': 0.0, 'start_lat': 34.4, 'start_lon': -94.37, 'end_lat': 0.0, 'end_lon': 0.0, 'len': 0.6, 'wid': 17, 'ns': 1, 'sn': 1, 'sg': 1, 'f1': 113, 'f2': 0, 'f3': 0, 'f4': 0, 'fc': 0}, {'id': 5, 'om': 5, 'data_source': 5, 'yr': 1950, 'mo': 1, 'dy': 25, 'date': '1/25/1950', 'tz': 3, 'states': 'MO', 'stf': 29, 'stn': 2, 'magnitude': 2, 'inj': 5, 'fat': 0, 'loss': 5.0, 'closs': 0.0, 'start_lat': 37.6, 'start_lon': -90.68, 'end_lat': 37.63, 'end_lon': -90.65, 'len': 2.3, 'wid': 300, 'ns': 1, 'sn': 1, 'sg': 1, 'f1': 93, 'f2': 0, 'f3': 0, 'f4': 0, 'fc': 0}, {'id': 6, 'om': 6, 'data_source': 5, 'yr': 1950, 'mo': 1, 'dy': 25, 'date': '1/25/1950', 'tz': 3, 'states': 'IL', 'stf': 17, 'stn': 3, 'magnitude': 2, 'inj': 0, 'fat': 0, 'loss': 5.0, 'closs': 0.0, 'start_lat': 41.17, 'start_lon': -87.33, 'end_lat': 0.0, 'end_lon': 0.0, 'len': 0.1, 'wid': 100, 'ns': 1, 'sn': 1, 'sg': 1, 'f1': 91, 'f2': 0, 'f3': 0, 'f4': 0, 'fc': 0}, {'id': 7, 'om': 7, 'data_source': 5, 'yr': 1950, 'mo': 1, 'dy': 26, 'date': '1/26/1950', 'tz': 3, 'states': 'TX', 'stf': 48, 'stn': 1, 'magnitude': 2, 'inj': 2, 'fat': 0, 'loss': 0.0, 'closs': 0.0, 'start_lat': 26.88, 'start_lon': -98.12, 'end_lat': 26.88, 'end_lon': -98.05, 'len': 4.7, 'wid': 133, 'ns': 1, 'sn': 1, 'sg': 1, 'f1': 47, 'f2': 0, 'f3': 0, 'f4': 0, 'fc': 0}, {'id': 8, 'om': 8, 'data_source': 5, 'yr': 1950, 'mo': 2, 'dy': 11, 'date': '2/11/1950', 'tz': 3, 'states': 'TX', 'stf': 48, 'stn': 2, 'magnitude': 2, 'inj': 0, 'fat': 0, 'loss': 4.0, 'closs': 0.0, 'start_lat': 29.42, 'start_lon': -95.25, 'end_lat': 29.52, 'end_lon': -95.13, 'len': 9.9, 'wid': 400, 'ns': 1, 'sn': 1, 'sg': 1, 'f1': 39, 'f2': 0, 'f3': 0, 'f4': 0, 'fc': 0}  ... displaying 10 of 63645 total bound parameter sets ...  {'id': 63644, 'om': 617023, 'data_source': 5, 'yr': 2018, 'mo': 12, 'dy': 31, 'date': '12/31/2018', 'tz': 3, 'states': 'IN', 'stf': 18, 'stn': 0, 'magnitude': 1, 'inj': 0, 'fat': 0, 'loss': 50000.0, 'closs': 0.0, 'start_lat': 38.1813, 'start_lon': -86.8863, 'end_lat': 38.2006, 'end_lon': -86.8585, 'len': 2.01, 'wid': 50, 'ns': 1, 'sn': 1, 'sg': 1, 'f1': 147, 'f2': 0, 'f3': 0, 'f4': 0, 'fc': 0}, {'id': 63645, 'om': 617024, 'data_source': 5, 'yr': 2018, 'mo': 12, 'dy': 31, 'date': '12/31/2018', 'tz': 3, 'states': 'IN', 'stf': 18, 'stn': 0, 'magnitude': 1, 'inj': 0, 'fat': 0, 'loss': 20000.0, 'closs': 0.0, 'start_lat': 38.0935, 'start_lon': -86.0869, 'end_lat': 38.1, 'end_lon': -86.04700000000001, 'len': 2.2, 'wid': 140, 'ns': 1, 'sn': 1, 'sg': 1, 'f1': 61, 'f2': 0, 'f3': 0, 'f4': 0, 'fc': 0})]
# (Background on this error at: http://sqlalche.me/e/gkpj)
